# %%
import pandas as pd 
import numpy as np

#데이터 불러오기

df_delete = pd.read_csv('dataset/delete_null.csv')
df_mean = pd.read_csv('dataset/mean_null.csv')
df_mode = pd.read_csv('dataset/mode_null.csv')

# %%
#스케일링 도중 생성된 결측행 제거
df_delete = df_delete.dropna()
df_mode = df_mode.dropna()
df_mean = df_mean.dropna()

# %% [markdown]
# ### Trainset / testset 분할

# %%
X = df_delete.drop(['Total_slp_wd_standard','SitTime_standard','Total_slp_wd_scaled','SitTime_scaled','BMI'],axis='columns') 
y = df_delete['BMI']

# %%
X
# Out:
#       sex   age  D_1_1  Total_slp_wd  BP1  BO1  BE5_1  BP5  SitTime
# 0     1.0  13.0    3.0         480.0  4.0  5.0    1.0  2.0    540.0
# 1     1.0  16.0    2.0         420.0  3.0  3.0    1.0  2.0    540.0
# 2     2.0  15.0    2.0         540.0  3.0  4.0    1.0  2.0    600.0
# 3     2.0  17.0    3.0         540.0  3.0  4.0    1.0  1.0   1020.0
# 4     1.0  12.0    2.0         480.0  3.0  2.0    1.0  2.0    600.0
# ...   ...   ...    ...           ...  ...  ...    ...  ...      ...
# 1520  2.0  16.0    2.0         600.0  4.0  3.0    1.0  2.0    660.0
# 1521  2.0  16.0    2.0         720.0  3.0  3.0    1.0  2.0    720.0
# 1522  1.0  14.0    3.0         570.0  3.0  3.0    1.0  2.0    420.0
# 1523  2.0  12.0    2.0         660.0  3.0  4.0    1.0  2.0    630.0
# 1524  2.0  12.0    1.0         510.0  3.0  2.0    3.0  2.0    450.0
#
# [1510 rows x 9 columns]

# %%
y.value_counts()
# Out:
# 0.0    1268
# 1.0     242
# Name: BMI, dtype: int64

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

# test_size : 테스트 데이터셋의 비율(float)이나 갯수(int) 
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, stratify=y, random_state=3)

# %%
y_test.value_counts()
# Out:
# 0.0    317
# 1.0     61
# Name: BMI, dtype: int64

# %% [markdown]
# # 모델링 (random forest)

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import KFold, GridSearchCV
from sklearn.model_selection import StratifiedKFold

#rf = RandomForestClassifier(n_estimators=100, oob_score=True, random_state=123456)
#rf.fit(X_train, y_train)

#최적 파라미터 값 찾기
params = { 'n_estimators' : [10, 100,200],
           'max_depth' : [6, 8, 10],
           'min_samples_leaf' : [3,5 ,7],
           'min_samples_split' : [2,3,6]}

rf_clf = RandomForestClassifier(random_state = 0, n_jobs = -1)
kfold = KFold(n_splits=5, shuffle=True, random_state=0) #업샘플링할때
skf = StratifiedKFold(n_splits=5, shuffle=True, random_state=0) #업샘플링 하지 않았을때
grid_cv = GridSearchCV(rf_clf, param_grid = params, cv = kfold, n_jobs = -1)
grid_cv.fit(X_train, y_train)

print('최적 하이퍼 파라미터: ', grid_cv.best_params_)
print('최고 예측 정확도: {:.4f}'.format(grid_cv.best_score_))
# Out:
# 최적 하이퍼 파라미터:  {'max_depth': 8, 'min_samples_leaf': 7, 'min_samples_split': 2, 'n_estimators': 100}
# 최고 예측 정확도: 0.8914

# %%
scores_df = pd.DataFrame(grid_cv.cv_results_)
scores_df
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        0.045277      0.009866         0.017354        0.002646
# 1        0.279451      0.014430         0.038098        0.009193
# 2        0.675593      0.041806         0.068816        0.012568
# 3        0.043882      0.007108         0.015957        0.005389
# 4        0.385569      0.055495         0.044481        0.010241
# ..            ...           ...              ...             ...
# 76       0.506845      0.084893         0.043684        0.012732
# 77       0.773533      0.021836         0.077192        0.014476
# 78       0.052459      0.002863         0.036103        0.008112
# 79       0.481512      0.080191         0.040492        0.007792
# 80       0.651458      0.029501         0.043484        0.005870
#
#    param_max_depth param_min_samples_leaf param_min_samples_split  \
# 0                6                      3                       2
# 1                6                      3                       2
# 2                6                      3                       2
# 3                6                      3                       3
# 4                6                      3                       3
# ..             ...                    ...                     ...
# 76              10                      7                       3
# 77              10                      7                       3
# 78              10                      7                       6
# 79              10                      7                       6
# 80              10                      7                       6
#
#    param_n_estimators                                             params  \
# 0                  10  {'max_depth': 6, 'min_samples_leaf': 3, 'min_s...
# 1                 100  {'max_depth': 6, 'min_samples_leaf': 3, 'min_s...
# 2                 200  {'max_depth': 6, 'min_samples_leaf': 3, 'min_s...
# 3                  10  {'max_depth': 6, 'min_samples_leaf': 3, 'min_s...
# 4                 100  {'max_depth': 6, 'min_samples_leaf': 3, 'min_s...
# ..                ...                                                ...
# 76                100  {'max_depth': 10, 'min_samples_leaf': 7, 'min_...
# 77                200  {'max_depth': 10, 'min_samples_leaf': 7, 'min_...
# 78                 10  {'max_depth': 10, 'min_samples_leaf': 7, 'min_...
# 79                100  {'max_depth': 10, 'min_samples_leaf': 7, 'min_...
# 80                200  {'max_depth': 10, 'min_samples_leaf': 7, 'min_...
#
#     split0_test_score  split1_test_score  split2_test_score  \
# 0            0.876652           0.841410           0.871681
# 1            0.894273           0.837004           0.884956
# 2            0.894273           0.841410           0.889381
# 3            0.876652           0.841410           0.871681
# 4            0.894273           0.837004           0.884956
# ..                ...                ...                ...
# 76           0.894273           0.841410           0.893805
# 77           0.894273           0.841410           0.889381
# 78           0.894273           0.850220           0.880531
# 79           0.894273           0.841410           0.893805
# 80           0.894273           0.841410           0.889381
#
#     split3_test_score  split4_test_score  mean_test_score  std_test_score  \
# 0            0.920354           0.902655         0.882550        0.027125
# 1            0.911504           0.889381         0.883424        0.024895
# 2            0.911504           0.893805         0.886075        0.023578
# 3            0.920354           0.902655         0.882550        0.027125
# 4            0.911504           0.889381         0.883424        0.024895
# ..                ...                ...              ...             ...
# 76           0.915929           0.889381         0.886960        0.024577
# 77           0.915929           0.889381         0.886075        0.024394
# 78           0.898230           0.880531         0.880757        0.016856
# 79           0.915929           0.889381         0.886960        0.024577
# 80           0.915929           0.889381         0.886075        0.024394
#
#     rank_test_score
# 0                49
# 1                40
# 2                19
# 3                49
# 4                40
# ..              ...
# 76               10
# 77               19
# 78               61
# 79               10
# 80               19
#
# [81 rows x 17 columns]

# %%
df_results = scores_df[['params', 'mean_test_score', 'rank_test_score', \
           'split0_test_score', 'split1_test_score', 'split2_test_score','split3_test_score','split4_test_score']]

# %%
df_results.sort_values(by='rank_test_score')
# Out:
#                                                params  mean_test_score  \
# 52  {'max_depth': 8, 'min_samples_leaf': 7, 'min_s...         0.891377
# 46  {'max_depth': 8, 'min_samples_leaf': 7, 'min_s...         0.891377
# 49  {'max_depth': 8, 'min_samples_leaf': 7, 'min_s...         0.891377
# 25  {'max_depth': 6, 'min_samples_leaf': 7, 'min_s...         0.888729
# 19  {'max_depth': 6, 'min_samples_leaf': 7, 'min_s...         0.888729
# ..                                                ...              ...
# 30  {'max_depth': 8, 'min_samples_leaf': 3, 'min_s...         0.870169
# 33  {'max_depth': 8, 'min_samples_leaf': 3, 'min_s...         0.870169
# 12  {'max_depth': 6, 'min_samples_leaf': 5, 'min_s...         0.866641
# 15  {'max_depth': 6, 'min_samples_leaf': 5, 'min_s...         0.866641
# 9   {'max_depth': 6, 'min_samples_leaf': 5, 'min_s...         0.866641
#
#     rank_test_score  split0_test_score  split1_test_score  split2_test_score  \
# 52                1           0.903084           0.841410           0.902655
# 46                1           0.903084           0.841410           0.902655
# 49                1           0.903084           0.841410           0.902655
# 25                4           0.898678           0.837004           0.893805
# 19                4           0.898678           0.837004           0.893805
# ..              ...                ...                ...                ...
# 30               76           0.881057           0.828194           0.871681
# 33               76           0.881057           0.828194           0.871681
# 12               79           0.872247           0.823789           0.876106
# 15               79           0.872247           0.823789           0.876106
# 9                79           0.872247           0.823789           0.876106
#
#     split3_test_score  split4_test_score
# 52           0.920354           0.889381
# 46           0.920354           0.889381
# 49           0.920354           0.889381
# 25           0.911504           0.902655
# 19           0.911504           0.902655
# ..                ...                ...
# 30           0.889381           0.880531
# 33           0.889381           0.880531
# 12           0.880531           0.880531
# 15           0.880531           0.880531
# 9            0.880531           0.880531
#
# [81 rows x 8 columns]

# %% [markdown]
# # 모델 퍼모먼스 함수

# %% [markdown]
# ### 업샘플링 데이터 시,  단순 교차검증을 사용

# %%
from sklearn.model_selection import cross_val_score

scores = cross_val_score(grid_cv, X_test, y_test, cv=5)
scores_re = cross_val_score(grid_cv, X_test, y_test, cv=5, scoring='recall')
scores_pre = cross_val_score(grid_cv, X_test, y_test, cv=5, scoring='precision')
print("Accuracy mean : ", scores.mean())
print("Recall mean : ",scores_re.mean())
print("Precision mean : ",scores_pre.mean())
# Out:
# Accuracy mean :  0.8517192982456139
# Recall mean :  0.2935897435897436
# Precision mean :  0.6016666666666667

# %% [markdown]
# ### 편향된 데이터이므로 계층별 k-겹 교차검증을 사용
#
# 평가할 때도 label의 분포를 유지시키며 cv별 올바른 평가를 위함

# %%
from sklearn.model_selection import StratifiedKFold

skf = StratifiedKFold(n_splits=5, shuffle=True, random_state=0)

scores = cross_val_score(grid_cv, X_test, y_test, cv=skf)
scores_re = cross_val_score(grid_cv, X_test, y_test, cv=skf, scoring='recall')
scores_pre = cross_val_score(grid_cv, X_test, y_test, cv=skf, scoring='precision')
print("Accuracy mean : ", scores.mean())
print("Recall mean : ",scores_re.mean())
print("Precision mean : ",scores_pre.mean())
# Out:
# Accuracy mean :  0.8756491228070177
# Recall mean :  0.3128205128205128
# Precision mean :  0.7928571428571429

# %%
from sklearn.metrics import confusion_matrix
from sklearn.metrics import roc_auc_score
def model_evaluation(label, predict):
    cf_matrix = confusion_matrix(label, predict)
    Accuracy = (cf_matrix[0][0] + cf_matrix[1][1]) / sum(sum(cf_matrix))
    Precision = cf_matrix[1][1] / (cf_matrix[1][1] + cf_matrix[0][1])
    Recall = cf_matrix[1][1] / (cf_matrix[1][1] + cf_matrix[1][0])
    Specificity = cf_matrix[0][0] / (cf_matrix[0][0] + cf_matrix[0][1])
    F1_Score = (2 * Recall * Precision) / (Recall + Precision)
    F2_Score = (5 * Recall * Precision) / (Recall + 4*Precision)
    
    print("Accuracy: ", Accuracy)
    print("Precision: ", Precision)
    print("Recall: ", Recall)
    print("Specificity: ", Specificity)
    print("F1-Score: ", F1_Score)
    print("F2-Score: ", F2_Score)
    print("auc score: " , roc_auc_score(label, np.round(predict,0)))

# %%
predicted = grid_cv.predict(X_test)
print(confusion_matrix(y_test, predicted))
print(model_evaluation(y_test, predicted))
# Out:
# [[311   6]
#  [ 36  25]]
# Accuracy:  0.8888888888888888
# Precision:  0.8064516129032258
# Recall:  0.4098360655737705
# Specificity:  0.9810725552050473
# F1-Score:  0.5434782608695652
# F2-Score:  0.4545454545454546
# auc score:  0.695454310389409
# None

# %% [markdown]
# # 변수 중요도
#
# 참조 https://eli5.readthedocs.io/en/latest/blackbox/permutation_importance.html

# %%
import eli5
from eli5.sklearn import PermutationImportance 

perm = PermutationImportance(grid_cv, scoring = "f1", random_state = 0).fit(X_train, y_train) 
df_impt = eli5.show_weights(perm, top = 80, feature_names = X_train.columns.tolist())

# 변수중요도 추출
df_impt
# Out:
#     <style>
#     table.eli5-weights tr:hover {
#         filter: brightness(85%);
#     }
# </style>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#         <table class="eli5-weights eli5-feature-importances" style="border-collapse: collapse; border: none; margin-top: 0em; table-layout: auto;">
#     <thead>
#     <tr style="border: none;">
#         <th style="padding: 0 1em 0 0.5em; text-align: right; border: none;">Weight</th>
#         <th style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">Feature</th>
#     </tr>
#     </thead>
#     <tbody>
#
#         <tr style="background-color: hsl(120, 100.00%, 80.00%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.4993
#
#                     &plusmn; 0.0616
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 BO1
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 93.89%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0917
#
#                     &plusmn; 0.0300
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 age
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 94.67%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0755
#
#                     &plusmn; 0.0303
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 Total_slp_wd
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 94.85%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0719
#
#                     &plusmn; 0.0440
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 sex
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 97.74%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0222
#
#                     &plusmn; 0.0253
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 D_1_1
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 97.84%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0208
#
#                     &plusmn; 0.0150
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 BP1
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 98.08%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0176
#
#                     &plusmn; 0.0158
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 SitTime
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 99.24%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0047
#
#                     &plusmn; 0.0179
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 BE5_1
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 99.63%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0017
#
#                     &plusmn; 0.0040
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 BP5
#             </td>
#         </tr>
#
#
#     </tbody>
# </table>

# %%
perm = PermutationImportance(grid_cv, scoring = "f1", random_state = 42).fit(X_train, y_train) 
eli5.show_weights(perm, top = 80, feature_names = X_train.columns.tolist())
# Out:
#     <style>
#     table.eli5-weights tr:hover {
#         filter: brightness(85%);
#     }
# </style>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#         <table class="eli5-weights eli5-feature-importances" style="border-collapse: collapse; border: none; margin-top: 0em; table-layout: auto;">
#     <thead>
#     <tr style="border: none;">
#         <th style="padding: 0 1em 0 0.5em; text-align: right; border: none;">Weight</th>
#         <th style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">Feature</th>
#     </tr>
#     </thead>
#     <tbody>
#
#         <tr style="background-color: hsl(120, 100.00%, 80.00%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.4988
#
#                     &plusmn; 0.0500
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 BO1
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 93.02%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.1109
#
#                     &plusmn; 0.0368
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 sex
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 93.99%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0895
#
#                     &plusmn; 0.0182
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 age
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 95.11%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0668
#
#                     &plusmn; 0.0226
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 Total_slp_wd
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 97.87%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0204
#
#                     &plusmn; 0.0199
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 BP1
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 97.97%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0190
#
#                     &plusmn; 0.0120
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 SitTime
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 98.04%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0181
#
#                     &plusmn; 0.0127
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 D_1_1
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 99.30%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0041
#
#                     &plusmn; 0.0052
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 BP5
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 99.46%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0029
#
#                     &plusmn; 0.0078
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 BE5_1
#             </td>
#         </tr>
#
#
#     </tbody>
# </table>

# %%
perm = PermutationImportance(grid_cv, scoring = "recall", random_state = 42).fit(X_train, y_train) 
eli5.show_weights(perm, top = 80, feature_names = X_train.columns.tolist())
# Out:
#     <style>
#     table.eli5-weights tr:hover {
#         filter: brightness(85%);
#     }
# </style>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#         <table class="eli5-weights eli5-feature-importances" style="border-collapse: collapse; border: none; margin-top: 0em; table-layout: auto;">
#     <thead>
#     <tr style="border: none;">
#         <th style="padding: 0 1em 0 0.5em; text-align: right; border: none;">Weight</th>
#         <th style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">Feature</th>
#     </tr>
#     </thead>
#     <tbody>
#
#         <tr style="background-color: hsl(120, 100.00%, 80.00%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.4398
#
#                     &plusmn; 0.0405
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 BO1
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 93.16%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0950
#
#                     &plusmn; 0.0214
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 age
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 93.55%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0873
#
#                     &plusmn; 0.0379
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 sex
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 94.08%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0773
#
#                     &plusmn; 0.0252
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 Total_slp_wd
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 97.71%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0199
#
#                     &plusmn; 0.0193
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 D_1_1
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 97.80%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0188
#
#                     &plusmn; 0.0228
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 BP1
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 97.80%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0188
#
#                     &plusmn; 0.0113
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 SitTime
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 99.07%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0055
#
#                     &plusmn; 0.0070
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 BP5
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 99.20%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0044
#
#                     &plusmn; 0.0083
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 BE5_1
#             </td>
#         </tr>
#
#
#     </tbody>
# </table>

# %%
# 변수중요도 시각화
from sklearn.inspection import permutation_importance
import matplotlib.pyplot as plt

result = permutation_importance(grid_cv, X_train, y_train, n_repeats=10,
                                random_state=42, n_jobs=2)
sorted_idx = result.importances_mean.argsort()

plt.barh(X_train.columns[sorted_idx], sorted(result.importances_mean))
plt.title('Permutation Importance', fontsize=18)
plt.ylabel('Feature name', fontsize=15)
plt.show()
# Out:
#   File "<ipython-input-23-f1f35dff6b5a>", line 5
#     result = permutation_importance(grid_cv, scoring = "f1",X_train, y_train, n_repeats=10,
#                                                             ^
# SyntaxError: positional argument follows keyword argument
