# %%
import pandas as pd 
import numpy as np

#데이터 불러오기

df = pd.read_csv('Dataset csv file.csv',encoding ='CP949')
df
# Out:
# C:\Users\rlagy\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3071: DtypeWarning: Columns (208,219,293,294,300,332,345,366,455,461,496,586,643,678) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#             mod_d          ID    ID_fam  year  region  town_t  apt_t   psu  \
# 0     2020.09.01.  A651172801  A6511728  2016       1       1      2  A651
# 1     2020.09.01.  A651172802  A6511728  2016       1       1      2  A651
# 2     2020.09.01.  A651183001  A6511830  2016       1       1      2  A651
# 3     2020.09.01.  A651183002  A6511830  2016       1       1      2  A651
# 4     2020.09.01.  A651183003  A6511830  2016       1       1      2  A651
# ...           ...         ...       ...   ...     ...     ...    ...   ...
# 8145  2020.09.01.  R654353001  R6543530  2016       8       2      2  R654
# ...

# %%
df_target = df[['HE_wc','HE_TG','HE_HDL_st2','HE_sbp','HE_dbp','HE_glu']]
column = ['HE_wc','HE_TG','HE_HDL_st2','HE_sbp','HE_dbp','HE_glu']

# %%
metabolic = []

for i in range(df_target.shape[0]):
    if ((list(df_target[column].iloc[i])[0] >= 90 ) & (list(df_target[column].iloc[i])[1] >= 150 )& (list(df_target[column].iloc[i])[2] < 40 )) == True:
         metabolic.append(1)
        
    elif ((list(df_target[column].iloc[i])[0] >= 90 ) & (list(df_target[column].iloc[i])[1] >= 150 )& (list(df_target[column].iloc[i])[3] >= 130 )) == True:
         metabolic.append(1)
        
    elif ((list(df_target[column].iloc[i])[0] >= 90 ) & (list(df_target[column].iloc[i])[1] >= 150 )& (list(df_target[column].iloc[i])[4] >= 85 )) == True:
         metabolic.append(1)
        
    elif ((list(df_target[column].iloc[i])[0] >= 90 ) & (list(df_target[column].iloc[i])[1] >= 150 )& (list(df_target[column].iloc[i])[5] >= 100 )) == True:
         metabolic.append(1)
        
    elif ((list(df_target[column].iloc[i])[1] >= 150 ) & (list(df_target[column].iloc[i])[2] < 40 )& (list(df_target[column].iloc[i])[3] >= 130 )) == True:
         metabolic.append(1)
        
    elif ((list(df_target[column].iloc[i])[1] >= 150 ) & (list(df_target[column].iloc[i])[2] < 40 )& (list(df_target[column].iloc[i])[4] >= 85 )) == True:
         metabolic.append(1)
        
    elif ((list(df_target[column].iloc[i])[1] >= 150 ) & (list(df_target[column].iloc[i])[2] < 40 )& (list(df_target[column].iloc[i])[5] >= 100 )) == True:
         metabolic.append(1)
    elif ((list(df_target[column].iloc[i])[2] < 40 ) & (list(df_target[column].iloc[i])[3] >=130 )& (list(df_target[column].iloc[i])[5] >= 100 )) == True:
         metabolic.append(1)
        
    elif ((list(df_target[column].iloc[i])[2] < 40 ) & (list(df_target[column].iloc[i])[4] >=85 )& (list(df_target[column].iloc[i])[5] >= 100 )) == True:
         metabolic.append(1)
    else:
        metabolic.append(0)
#raw_male['suicide'] = suicide

# %%
df['metabolic_YN'] = metabolic
df.metabolic_YN.value_counts()
# Out:
# 0    7200
# 1     950
# Name: metabolic_YN, dtype: int64

# %%
df_men = df[df['sex']==1]
df_men.metabolic_YN.value_counts()
# Out:
# 0    3055
# 1     610
# Name: metabolic_YN, dtype: int64

# %%
df_men[df_men['age']<=20].metabolic_YN.value_counts()
# 청소년의 경우 대사증후군이 있는 것으로 판단됨
#따라서, 변수 추출시 성인만 한정된 것으로 하기 힘듬
# 설명변수는 어린아이부터 성인까지 포함된 변수를 추출함
# Out:
# 0    932
# 1     10
# Name: metabolic_YN, dtype: int64

# %% [markdown]
# # 사용한 변수
# 나이, 교육, 우울증 의사진단 여부, 활동제한 여부, 1년간 손상 발생여부,1년간 입원이용 여부, 주관적 체형인식, 1년간 체중 변화 여부, 주중 하루 평균 수면시간,평소 스트레스 인지 정도,2주이상 연속 우울감 여부, 1년간 자살 생각 여부,일_고강도 신체활동 여부
#
# 이유: 청소년의 경우도 대사증후군이 있으므로, 성인만 해당하는 변수는 제거<br>
# 또한, 건강설문 이환 의 카테고리에 너무 많은 변수가 존재.  <br>
# 이를 가공하기에는 많은 시간이 소요되므로, 사람들의 행태적 특성을 이용하여 대사증후군을 예측하고자 함

# %%
df_all = df_men[['age', 'edu', 'DF2_dg','LQ4_00','AC1_yr','MH1_yr','BO1', 'BO1_1','Total_slp_wk','BP1','BP5','BP6_10','BE3_71','metabolic_YN']]
df_all
# Out:
#       age  edu  DF2_dg  LQ4_00  AC1_yr  MH1_yr  BO1  BO1_1  Total_slp_wk  BP1  \
# 0      61  4.0     0.0     2.0     2.0     2.0  4.0    1.0         480.0  4.0
# 3      39  4.0     0.0     2.0     2.0     2.0  5.0    1.0         360.0  2.0
# 8      38  4.0     0.0     2.0     1.0     2.0  4.0    1.0         420.0  2.0
# 10      3  1.0     8.0     2.0     2.0     2.0  8.0    8.0        8888.0  8.0
# 13     61  4.0     0.0     2.0     2.0     2.0  4.0    1.0         330.0  4.0
# ...   ...  ...     ...     ...     ...     ...  ...    ...           ...  ...
# 8137    9  1.0     8.0     2.0     2.0     2.0  1.0    8.0        8888.0  8.0
# 8138   46  3.0     0.0     1.0     2.0     2.0  3.0    1.0         420.0  3.0
# 8142   46  4.0     0.0     2.0     2.0     2.0  3.0    1.0         480.0  3.0
# 8145   75  3.0     0.0     2.0     2.0     2.0  5.0    3.0         420.0  4.0
# 8148   56  3.0     0.0     2.0     2.0     2.0  4.0    1.0         420.0  2.0
#
# ...

# %% [markdown]
# # 결측치 확인

# %%
df_all.isnull().sum()
# Out:
# age               0
# edu             332
# DF2_dg          168
# LQ4_00          168
# AC1_yr          168
# MH1_yr          168
# BO1             168
# BO1_1           168
# Total_slp_wk    168
# BP1             168
# BP5             168
# BP6_10          168
# BE3_71          168
# metabolic_YN      0
# dtype: int64

# %%
df_all.dropna(inplace=True)
# Out:
# <ipython-input-175-ea1ffc571624>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_all.dropna(inplace=True)

# %%
df_all.isnull().sum()
# Out:
# age             0
# edu             0
# DF2_dg          0
# LQ4_00          0
# AC1_yr          0
# MH1_yr          0
# BO1             0
# BO1_1           0
# Total_slp_wk    0
# BP1             0
# BP5             0
# BP6_10          0
# BE3_71          0
# metabolic_YN    0
# dtype: int64

# %%
df_all
# Out:
#       age  edu  DF2_dg  LQ4_00  AC1_yr  MH1_yr  BO1  BO1_1  Total_slp_wk  BP1  \
# 0      61  4.0     0.0     2.0     2.0     2.0  4.0    1.0         480.0  4.0
# 3      39  4.0     0.0     2.0     2.0     2.0  5.0    1.0         360.0  2.0
# 8      38  4.0     0.0     2.0     1.0     2.0  4.0    1.0         420.0  2.0
# 10      3  1.0     8.0     2.0     2.0     2.0  8.0    8.0        8888.0  8.0
# 13     61  4.0     0.0     2.0     2.0     2.0  4.0    1.0         330.0  4.0
# ...   ...  ...     ...     ...     ...     ...  ...    ...           ...  ...
# 8137    9  1.0     8.0     2.0     2.0     2.0  1.0    8.0        8888.0  8.0
# 8138   46  3.0     0.0     1.0     2.0     2.0  3.0    1.0         420.0  3.0
# 8142   46  4.0     0.0     2.0     2.0     2.0  3.0    1.0         480.0  3.0
# 8145   75  3.0     0.0     2.0     2.0     2.0  5.0    3.0         420.0  4.0
# 8148   56  3.0     0.0     2.0     2.0     2.0  4.0    1.0         420.0  2.0
#
# ...

# %% [markdown]
# # 데이터 8,  9 (모름, 무응답)에 대해 결측치 처리

# %%
# 주관적 건강상태 [D_1_1]] (순서)
from pandas.api.types import CategoricalDtype
def delete(col):
    print(df_all[col].value_counts())
    print("==========================")
    df_all.loc[df_all[col] == 8, col] = np.nan
    df_all.loc[df_all[col] == 9, col] = np.nan
    df_all[col] = df_all[col].astype(CategoricalDtype(ordered=True))
    print(df_all[col].value_counts())

# %%
delete('DF2_dg')
# Out:
# 0.0    2425
# 8.0     848
# 1.0      60
# Name: DF2_dg, dtype: int64
# ...
# 0.0    2425
# 1.0      60
# Name: DF2_dg, dtype: int64
# C:\Users\rlagy\anaconda3\lib\site-packages\pandas\core\indexing.py:966: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[item] = s
# <ipython-input-178-7e816c5aee07>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_all[col] = df_all[col].astype(CategoricalDtype(ordered=True))

# %%
delete('LQ4_00')
# Out:
# 2.0    3126
# 1.0     206
# 9.0       1
# Name: LQ4_00, dtype: int64
# ...
# 2.0    3126
# 1.0     206
# Name: LQ4_00, dtype: int64
# <ipython-input-178-7e816c5aee07>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_all[col] = df_all[col].astype(CategoricalDtype(ordered=True))

# %%
delete('AC1_yr')
# Out:
# 2.0    3022
# 1.0     310
# 9.0       1
# Name: AC1_yr, dtype: int64
# ...
# 2.0    3022
# 1.0     310
# Name: AC1_yr, dtype: int64
# <ipython-input-178-7e816c5aee07>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_all[col] = df_all[col].astype(CategoricalDtype(ordered=True))

# %%
delete('MH1_yr')
# Out:
# 2.0    2970
# 1.0     360
# 9.0       3
# Name: MH1_yr, dtype: int64
# ...
# 2.0    2970
# 1.0     360
# Name: MH1_yr, dtype: int64
# <ipython-input-178-7e816c5aee07>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_all[col] = df_all[col].astype(CategoricalDtype(ordered=True))

# %%
delete('BO1')
# Out:
# 3.0    1175
# 4.0     976
# 2.0     531
# 8.0     258
# 1.0     205
# 5.0     183
# 9.0       5
# Name: BO1, dtype: int64
# ...
# 3.0    1175
# 4.0     976
# 2.0     531
# 1.0     205
# 5.0     183
# Name: BO1, dtype: int64
# <ipython-input-178-7e816c5aee07>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_all[col] = df_all[col].astype(CategoricalDtype(ordered=True))

# %%
delete('BO1_1')
# Out:
# 1.0    1631
# 8.0     848
# 3.0     515
# 2.0     334
# 9.0       5
# Name: BO1_1, dtype: int64
# ...
# 1.0    1631
# 3.0     515
# 2.0     334
# Name: BO1_1, dtype: int64
# <ipython-input-178-7e816c5aee07>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_all[col] = df_all[col].astype(CategoricalDtype(ordered=True))

# %%
delete('BP1')
# Out:
# 3.0    1597
# 2.0     569
# 8.0     567
# 4.0     479
# 1.0     114
# 9.0       7
# Name: BP1, dtype: int64
# ...
# 3.0    1597
# 2.0     569
# 4.0     479
# 1.0     114
# Name: BP1, dtype: int64
# <ipython-input-178-7e816c5aee07>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_all[col] = df_all[col].astype(CategoricalDtype(ordered=True))

# %% [markdown]
# BP5, BP6는 16년 성인이 비해당이므로 삭제

# %%
feature_columns = list(df_all.columns.difference(['BP5','BP6']))
feature_columns
# Out:
# ['AC1_yr',
#  'BE3_71',
#  'BO1',
#  'BO1_1',
#  'BP1',
#  'BP6_10',
#  'DF2_dg',
#  'LQ4_00',
#  'MH1_yr',
#  'Total_slp_wk',
#  'age',
#  'edu',
#  'metabolic_YN']

# %%
delete('BE3_71')
# Out:
# 2.0    2627
# 8.0     567
# 1.0     135
# 9.0       4
# Name: BE3_71, dtype: int64
# ...
# 2.0    2627
# 1.0     135
# Name: BE3_71, dtype: int64
# <ipython-input-178-7e816c5aee07>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_all[col] = df_all[col].astype(CategoricalDtype(ordered=True))

# %%
df_real = df_all[feature_columns]
df_real.isnull().sum()
# Out:
# AC1_yr            1
# BE3_71          571
# BO1             263
# BO1_1           853
# BP1             574
# BP6_10            0
# DF2_dg          848
# LQ4_00            1
# MH1_yr            3
# Total_slp_wk      0
# age               0
# edu               0
# metabolic_YN      0
# dtype: int64

# %%
840/3333
# Out:
# 0.252025202520252

# %% [markdown]
# ## BO1_1 ,DF2_dg  결측치가 20%이상이므로 삭제

# %%
feature_columns = list(df_all.columns.difference(['BP5','BP6','BO1_1','DF2_dg']))

# %%
df_real = df_all[feature_columns]
df_real
# Out:
#      AC1_yr BE3_71  BO1  BP1  BP6_10 LQ4_00 MH1_yr  Total_slp_wk  age  edu  \
# 0       2.0    2.0  4.0  4.0     8.0    2.0    2.0         480.0   61  4.0
# 3       2.0    2.0  5.0  2.0     8.0    2.0    2.0         360.0   39  4.0
# 8       1.0    2.0  4.0  2.0     8.0    2.0    2.0         420.0   38  4.0
# 10      2.0    NaN  NaN  NaN     8.0    2.0    2.0        8888.0    3  1.0
# 13      2.0    2.0  4.0  4.0     8.0    2.0    2.0         330.0   61  4.0
# ...     ...    ...  ...  ...     ...    ...    ...           ...  ...  ...
# 8137    2.0    NaN  1.0  NaN     8.0    2.0    2.0        8888.0    9  1.0
# 8138    2.0    2.0  3.0  3.0     8.0    1.0    2.0         420.0   46  3.0
# 8142    2.0    2.0  3.0  3.0     8.0    2.0    2.0         480.0   46  4.0
# 8145    2.0    2.0  5.0  4.0     8.0    2.0    2.0         420.0   75  3.0
# 8148    2.0    2.0  4.0  2.0     8.0    2.0    2.0         420.0   56  3.0
#
#       metabolic_YN
# 0                0
# 3                1
# ...

# %%
df_real.isnull().sum()
# Out:
# AC1_yr            1
# BE3_71          571
# BO1             263
# BP1             574
# BP6_10            0
# LQ4_00            1
# MH1_yr            3
# Total_slp_wk      0
# age               0
# edu               0
# metabolic_YN      0
# dtype: int64

# %% [markdown]
# # 나머지 결측행 제거 (20% 미만이므로)

# %%
df_real.dropna(inplace=True)
# Out:
# <ipython-input-90-e9c35506fd4f>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_real.dropna(inplace=True)

# %%
df_real = df_real.reset_index().iloc[:,2:]
df_real
# Out:
#      AC1_yr BE3_71  BO1  BP1  BP6_10 LQ4_00 MH1_yr  Total_slp_wk  age  edu  \
# 0       2.0    2.0  4.0  4.0     8.0    2.0    2.0         480.0   61  4.0
# 1       2.0    2.0  5.0  2.0     8.0    2.0    2.0         360.0   39  4.0
# 2       1.0    2.0  4.0  2.0     8.0    2.0    2.0         420.0   38  4.0
# 3       2.0    2.0  4.0  4.0     8.0    2.0    2.0         330.0   61  4.0
# 4       2.0    2.0  3.0  3.0     8.0    2.0    2.0         420.0   49  4.0
# ...     ...    ...  ...  ...     ...    ...    ...           ...  ...  ...
# 2748    2.0    2.0  4.0  3.0     2.0    2.0    2.0         420.0   13  1.0
# 2749    2.0    2.0  3.0  3.0     8.0    1.0    2.0         420.0   46  3.0
# 2750    2.0    2.0  3.0  3.0     8.0    2.0    2.0         480.0   46  4.0
# 2751    2.0    2.0  5.0  4.0     8.0    2.0    2.0         420.0   75  3.0
# 2752    2.0    2.0  4.0  2.0     8.0    2.0    2.0         420.0   56  3.0
#
#       metabolic_YN
# 0                0
# 1                1
# ...

# %% [markdown]
# 연속형 변수 2개 : Total_slp_wk, age <br>
# 나머지 : 명목형

# %%
#히스토그램
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

for df in df_real.columns:
    plt.hist(df_real[df])
    plt.ylabel('frequency')
    plt.rc('font', family='NanumGothic')  
    plt.title('변수 {}의 히스토그램'.format(df))
    plt.show()

# %%
sns.boxplot(df_real.Total_slp_wk)
#이상치 제거

# %%
sns.boxplot(df_real.age)

# %%
def remove_outlier(d_cp, column):
    
    fraud_column_data = d_cp[column]
    quan_25 = np.percentile(fraud_column_data, 25)
    quan_75 = np.percentile(fraud_column_data, 75)
    
    iqr = quan_75 - quan_25
    iqr = iqr * 1.5
    lowest = quan_25 - iqr
    highest = quan_75 + iqr
    outlier_index = fraud_column_data[(fraud_column_data<lowest) | (fraud_column_data > highest)].index
    d_cp.drop(outlier_index, axis=0, inplace=True)
    
    return d_cp

# %%
df_remove = remove_outlier(df_real, "Total_slp_wk")
df_remove
# Out:
#      AC1_yr BE3_71  BO1  BP1  BP6_10 LQ4_00 MH1_yr  Total_slp_wk  age  edu  \
# 0       2.0    2.0  4.0  4.0     8.0    2.0    2.0         480.0   61  4.0
# 1       2.0    2.0  5.0  2.0     8.0    2.0    2.0         360.0   39  4.0
# 2       1.0    2.0  4.0  2.0     8.0    2.0    2.0         420.0   38  4.0
# 3       2.0    2.0  4.0  4.0     8.0    2.0    2.0         330.0   61  4.0
# 4       2.0    2.0  3.0  3.0     8.0    2.0    2.0         420.0   49  4.0
# ...     ...    ...  ...  ...     ...    ...    ...           ...  ...  ...
# 2748    2.0    2.0  4.0  3.0     2.0    2.0    2.0         420.0   13  1.0
# 2749    2.0    2.0  3.0  3.0     8.0    1.0    2.0         420.0   46  3.0
# 2750    2.0    2.0  3.0  3.0     8.0    2.0    2.0         480.0   46  4.0
# 2751    2.0    2.0  5.0  4.0     8.0    2.0    2.0         420.0   75  3.0
# 2752    2.0    2.0  4.0  2.0     8.0    2.0    2.0         420.0   56  3.0
#
#       metabolic_YN
# 0                0
# 1                1
# ...

# %% [markdown]
# # 이상치가 제거됨을 확인!

# %%
sns.boxplot(df_remove.Total_slp_wk)

# %%
df_remove.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2738 entries, 0 to 2752
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   AC1_yr        2738 non-null   category
#  1   BE3_71        2738 non-null   category
#  2   BO1           2738 non-null   category
#  3   BP1           2738 non-null   category
#  4   BP6_10        2738 non-null   float64
#  5   LQ4_00        2738 non-null   category
#  6   MH1_yr        2738 non-null   category
#  7   Total_slp_wk  2738 non-null   float64
#  8   age           2738 non-null   int64
#  9   edu           2738 non-null   float64
#  10  metabolic_YN  2738 non-null   int64
# dtypes: category(6), float64(3), int64(2)
# memory usage: 145.1 KB

# %% [markdown]
# # 예 아니오 인 경우 명목형이므로 순서형에서 변경

# %%
df_remove['AC1_yr'] = df_remove['AC1_yr'].astype('int64')
df_remove['BE3_71'] = df_remove['BE3_71'].astype('int64')
df_remove['BP1'] = df_remove['BP1'].astype('int64')
df_remove['BP6_10'] = df_remove['BP6_10'].astype('int64')
df_remove['LQ4_00'] = df_remove['LQ4_00'].astype('int64')
df_remove['MH1_yr'] = df_remove['MH1_yr'].astype('int64')

# %%
df_remove.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2738 entries, 0 to 2752
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   AC1_yr        2738 non-null   int64
#  1   BE3_71        2738 non-null   int64
#  2   BO1           2738 non-null   category
#  3   BP1           2738 non-null   int64
#  4   BP6_10        2738 non-null   int64
#  5   LQ4_00        2738 non-null   int64
#  6   MH1_yr        2738 non-null   int64
#  7   Total_slp_wk  2738 non-null   float64
#  8   age           2738 non-null   int64
#  9   edu           2738 non-null   float64
#  10  metabolic_YN  2738 non-null   int64
# dtypes: category(1), float64(2), int64(8)
# memory usage: 238.2 KB

# %%
df_real.metabolic_YN.value_counts()
# Out:
# 0    2173
# 1     565
# Name: metabolic_YN, dtype: int64

# %%
X = df_real[list(df_real.columns.difference(['metabolic_YN']))]
y= df_real['metabolic_YN']

# %% [markdown]
# # 모델링 (Random forest)

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

# test_size : 테스트 데이터셋의 비율(float)이나 갯수(int) 
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, stratify=y, random_state=3)

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import KFold, GridSearchCV
from sklearn.model_selection import StratifiedKFold

#rf = RandomForestClassifier(n_estimators=100, oob_score=True, random_state=123456)
#rf.fit(X_train, y_train)

#최적 파라미터 값 찾기
params = { 'n_estimators' : [10, 100],
           'max_depth' : [6, 8, 10],
           'min_samples_leaf' : [3,5 ,7],
           'min_samples_split' : [2,3,6]}

rf_clf = RandomForestClassifier(random_state = 0, n_jobs = -1)
#kfold = KFold(n_splits=5, shuffle=True, random_state=0) #업샘플링할때
skf = StratifiedKFold(n_splits=5, shuffle=True, random_state=0) #업샘플링 하지 않았을때
grid_cv = GridSearchCV(rf_clf, param_grid = params, cv = skf, n_jobs = -1)
grid_cv.fit(X_train, y_train)

print('최적 하이퍼 파라미터: ', grid_cv.best_params_)
print('최고 예측 정확도: {:.4f}'.format(grid_cv.best_score_))
# Out:
# 최적 하이퍼 파라미터:  {'max_depth': 6, 'min_samples_leaf': 5, 'min_samples_split': 2, 'n_estimators': 100}
# 최고 예측 정확도: 0.8018

# %%
scores_df = pd.DataFrame(grid_cv.cv_results_)
scores_df
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        0.055052      0.005477         0.027726        0.015118
# 1        0.385368      0.042629         0.046675        0.006383
# 2        0.060437      0.005870         0.025731        0.005549
# 3        0.443225      0.018652         0.043682        0.008516
# 4        0.049866      0.004967         0.024135        0.009407
# 5        0.369835      0.027142         0.049666        0.012669
# 6        0.095152      0.040015         0.019347        0.006633
# 7        0.333707      0.016002         0.041489        0.010641
# 8        0.040891      0.002275         0.014164        0.002847
# 9        0.456261      0.016005         0.053517        0.021085
# 10       0.072606      0.025679         0.043882        0.019976
# 11       0.405893      0.030412         0.039022        0.011145
# 12       0.050378      0.005057         0.035430        0.017264
# ...

# %%
df_results = scores_df[['params', 'mean_test_score', 'rank_test_score', \
           'split0_test_score', 'split1_test_score', 'split2_test_score','split3_test_score','split4_test_score']]

# %%
df_results.sort_values(by='rank_test_score')
# Out:
#                                                params  mean_test_score  \
# 11  {'max_depth': 6, 'min_samples_leaf': 5, 'min_s...         0.801755
# 9   {'max_depth': 6, 'min_samples_leaf': 5, 'min_s...         0.801755
# 7   {'max_depth': 6, 'min_samples_leaf': 5, 'min_s...         0.801755
# 27  {'max_depth': 8, 'min_samples_leaf': 5, 'min_s...         0.801272
# 19  {'max_depth': 8, 'min_samples_leaf': 3, 'min_s...         0.801272
# 25  {'max_depth': 8, 'min_samples_leaf': 5, 'min_s...         0.801272
# 21  {'max_depth': 8, 'min_samples_leaf': 3, 'min_s...         0.801272
# 23  {'max_depth': 8, 'min_samples_leaf': 3, 'min_s...         0.801272
# 29  {'max_depth': 8, 'min_samples_leaf': 5, 'min_s...         0.801272
# 5   {'max_depth': 6, 'min_samples_leaf': 3, 'min_s...         0.800781
# 3   {'max_depth': 6, 'min_samples_leaf': 3, 'min_s...         0.800781
# 1   {'max_depth': 6, 'min_samples_leaf': 3, 'min_s...         0.800781
# ...

# %% [markdown]
# # 모델 퍼포먼스 (Evaluation)

# %%
from sklearn.metrics import confusion_matrix
from sklearn.metrics import roc_auc_score
def model_evaluation(label, predict):
    cf_matrix = confusion_matrix(label, predict)
    Accuracy = (cf_matrix[0][0] + cf_matrix[1][1]) / sum(sum(cf_matrix))
    Precision = cf_matrix[1][1] / (cf_matrix[1][1] + cf_matrix[0][1])
    Recall = cf_matrix[1][1] / (cf_matrix[1][1] + cf_matrix[1][0])
    Specificity = cf_matrix[0][0] / (cf_matrix[0][0] + cf_matrix[0][1])
    F1_Score = (2 * Recall * Precision) / (Recall + Precision)
    F2_Score = (5 * Recall * Precision) / (Recall + 4*Precision)
    
    print("Accuracy: ", Accuracy)
    print("Precision: ", Precision)
    print("Recall: ", Recall)
    print("Specificity: ", Specificity)
    print("F1-Score: ", F1_Score)
    print("F2-Score: ", F2_Score)
    print("auc score: " , roc_auc_score(label, np.round(predict,0)))

# %%
predicted = grid_cv.predict(X_test)
print(confusion_matrix(y_test, predicted))
print(model_evaluation(y_test, predicted))
# Out:
# [[533  11]
#  [131  10]]
# Accuracy:  0.7927007299270074
# Precision:  0.47619047619047616
# Recall:  0.07092198581560284
# Specificity:  0.9797794117647058
# F1-Score:  0.12345679012345681
# F2-Score:  0.08547008547008547
# auc score:  0.5253506987901544
# None

# %% [markdown]
# ## 데이터가 너무 편향되어 recall 이 형편이 없음.
# # 업샘플링 시도

# %%
#X_train, X_test, y_train, y_test
train_x = pd.concat([X_train,y_train], axis=1)
train_x
# Out:
#       AC1_yr  BE3_71  BO1  BP1  BP6_10  LQ4_00  MH1_yr  Total_slp_wk  age  \
# 1936       2       2  2.0    4       8       1       2         300.0   59
# 1653       2       2  2.0    2       8       2       2         540.0   47
# 246        2       2  5.0    2       8       2       2         360.0   46
# 1167       1       2  2.0    4       8       2       1         465.0   67
# 2393       1       2  2.0    3       2       2       1         340.0   18
# ...      ...     ...  ...  ...     ...     ...     ...           ...  ...
# 1735       2       2  3.0    3       8       2       1         480.0   47
# 1183       1       2  3.0    4       8       2       2         420.0   63
# 1697       2       2  3.0    2       8       2       2         570.0   54
# 80         2       2  3.0    3       8       2       2         420.0   53
# 1884       2       2  5.0    2       8       2       2         300.0   47
#
#       edu  metabolic_YN
# 1936  3.0             0
# 1653  3.0             0
# ...

# %%
df_class_0 = train_x[train_x['metabolic_YN'] == 0]
df_class_1 = train_x[train_x['metabolic_YN'] == 1]

df_class_1_over = df_class_1.sample(df_class_0.shape[0], replace=True, random_state=10)
df_over = pd.concat([df_class_0, df_class_1_over], axis=0)

# %%
X_res = df_over[feature_columns]
y_res = df_over[['metabolic_YN']]

# %%
X_res = X_res.iloc[:,:-1]

# %%
y_res.metabolic_YN.value_counts()
#동일함을 확인
# Out:
# 1    1629
# 0    1629
# Name: metabolic_YN, dtype: int64

# %% [markdown]
# # 업샘플링 모델링

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import KFold, GridSearchCV
from sklearn.model_selection import StratifiedKFold

#rf = RandomForestClassifier(n_estimators=100, oob_score=True, random_state=123456)
#rf.fit(X_train, y_train)

#최적 파라미터 값 찾기
params = { 'n_estimators' : [10, 20,30],
           'max_depth' : [4,6, 8, 10],
           'min_samples_leaf' : [3,5 ,7],
           'min_samples_split' : [2,3,6]}

rf_clf2 = RandomForestClassifier(random_state = 0, n_jobs = -1)
#kfold = KFold(n_splits=5, shuffle=True, random_state=0) #업샘플링할때
skf = StratifiedKFold(n_splits=5, shuffle=True, random_state=0) #업샘플링 하지 않았을때
grid_cv = GridSearchCV(rf_clf2, param_grid = params, cv = skf, n_jobs = -1)
grid_cv.fit(X_res, y_res)

print('최적 하이퍼 파라미터: ', grid_cv.best_params_)
print('최고 예측 정확도: {:.4f}'.format(grid_cv.best_score_))
# Out:
# 최적 하이퍼 파라미터:  {'max_depth': 10, 'min_samples_leaf': 3, 'min_samples_split': 2, 'n_estimators': 20}
# 최고 예측 정확도: 0.7901
# C:\Users\rlagy\anaconda3\lib\site-packages\sklearn\model_selection\_search.py:765: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   self.best_estimator_.fit(X, y, **fit_params)

# %%
scores_df = pd.DataFrame(grid_cv.cv_results_)
scores_df
# Out:
#      mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0         0.052464      0.002412         0.013359        0.001190
# 1         0.095941      0.004694         0.018550        0.004442
# 2         0.122672      0.025738         0.023338        0.008845
# 3         0.065225      0.006136         0.019549        0.004257
# 4         0.098536      0.008974         0.021742        0.008635
# ..             ...           ...              ...             ...
# 103       0.115087      0.021972         0.025792        0.004021
# 104       0.135170      0.017444         0.028301        0.004930
# 105       0.068983      0.017589         0.020614        0.005616
# 106       0.101283      0.018119         0.024499        0.008085
# 107       0.109920      0.005972         0.012367        0.003192
#
#     param_max_depth param_min_samples_leaf param_min_samples_split  \
# 0                 4                      3                       2
# ...

# %%
df_results = scores_df[['params', 'mean_test_score', 'rank_test_score', \
           'split0_test_score', 'split1_test_score', 'split2_test_score','split3_test_score','split4_test_score']]

# %%
df_results.sort_values(by='rank_test_score')
# Out:
#                                                params  mean_test_score  \
# 88  {'max_depth': 10, 'min_samples_leaf': 3, 'min_...         0.790051
# 82  {'max_depth': 10, 'min_samples_leaf': 3, 'min_...         0.790051
# 85  {'max_depth': 10, 'min_samples_leaf': 3, 'min_...         0.790051
# 89  {'max_depth': 10, 'min_samples_leaf': 3, 'min_...         0.787906
# 86  {'max_depth': 10, 'min_samples_leaf': 3, 'min_...         0.787906
# ..                                                ...              ...
# 25  {'max_depth': 4, 'min_samples_leaf': 7, 'min_s...         0.701976
# 19  {'max_depth': 4, 'min_samples_leaf': 7, 'min_s...         0.701976
# 7   {'max_depth': 4, 'min_samples_leaf': 3, 'min_s...         0.701664
# 4   {'max_depth': 4, 'min_samples_leaf': 3, 'min_s...         0.701664
# 1   {'max_depth': 4, 'min_samples_leaf': 3, 'min_s...         0.701664
#
#     rank_test_score  split0_test_score  split1_test_score  split2_test_score  \
# ...

# %%
predicted = grid_cv.predict(X_test)
print(confusion_matrix(y_test, predicted))
print(model_evaluation(y_test, predicted))
# Out:
# [[365 179]
#  [ 61  80]]
# Accuracy:  0.6496350364963503
# Precision:  0.3088803088803089
# Recall:  0.5673758865248227
# Specificity:  0.6709558823529411
# F1-Score:  0.4
# F2-Score:  0.48602673147023084
# auc score:  0.6191658844388819
# None

# %%
import eli5
from eli5.sklearn import PermutationImportance 

perm = PermutationImportance(grid_cv, scoring = "recall", random_state = 0).fit(X_res, y_res) 
df_impt = eli5.show_weights(perm, top = 80, feature_names = X_res.columns.tolist())

# 변수중요도 추출
df_impt
# Out:
# C:\Users\rlagy\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:143: FutureWarning: The sklearn.metrics.scorer module is  deprecated in version 0.22 and will be removed in version 0.24. The corresponding classes / functions should instead be imported from sklearn.metrics. Anything that cannot be imported from sklearn.metrics is now part of the private API.
#   warnings.warn(message, FutureWarning)
# C:\Users\rlagy\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:143: FutureWarning: The sklearn.feature_selection.base module is  deprecated in version 0.22 and will be removed in version 0.24. The corresponding classes / functions should instead be imported from sklearn.feature_selection. Anything that cannot be imported from sklearn.feature_selection is now part of the private API.
#   warnings.warn(message, FutureWarning)
#     <style>
#     table.eli5-weights tr:hover {
#         filter: brightness(85%);
#     }
# </style>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# ...

# %%
# 변수중요도 시각화
from sklearn.inspection import permutation_importance
import matplotlib.pyplot as plt

result = permutation_importance(grid_cv, X_res, y_res, n_repeats=10,
                                random_state=42, n_jobs=2)
sorted_idx = result.importances_mean.argsort()

plt.barh(X_train.columns[sorted_idx], sorted(result.importances_mean))
plt.title('대사증후군에 따른 변수 중요도', fontsize=12)
plt.ylabel('Feature name', fontsize=15)
plt.show()

# %% [markdown]
# # SVM 모델

# %% [markdown]
# ## 데이터 표준화
#
# 연속형 변수와 명목형 또는 순서형 변수 간의 간극을 좁히기 위해서 데이터를 모두 0과 1 사이의 범위로 통일화 시켜 SVM모델의 스케일링 문제를 해결해주기 위함이다.

# %% [markdown]
# X_res, y_res 적용

# %%
from sklearn.preprocessing import MinMaxScaler
transformer = MinMaxScaler()
standard = transformer.fit_transform(X_res)
standard
# Out:
# array([[1.        , 1.        , 0.25      , ..., 0.25      , 0.69117647,
#         0.66666667],
#        [1.        , 1.        , 0.25      , ..., 0.75      , 0.51470588,
#         0.66666667],
#        [1.        , 1.        , 1.        , ..., 0.375     , 0.5       ,
#         1.        ],
#        ...,
#        [1.        , 1.        , 0.75      , ..., 0.5       , 0.19117647,
#         0.66666667],
#        [1.        , 1.        , 1.        , ..., 0.5       , 0.92647059,
#         0.66666667],
#        [1.        , 1.        , 0.5       , ..., 0.5       , 0.82352941,
#         1.        ]])

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.svm import SVC 

param_grid = [ { 'C' : [0.1, 1, 10 ], 'kernel': [ 'poly' ], 'gamma' : [ 1,0.1 ]}]
grid_search = GridSearchCV(SVC(),param_grid, cv=2, return_train_score = True)
grid_search.fit(X_train, y_train)
print("best parameters : {}".format(grid_search.best_params_))
print('최적 하이퍼 파라미터: ', grid_search.best_params_)
print('최고 예측 정확도: {:.4f}'.format(grid_search.best_score_))

# %%
scores_df = pd.DataFrame(grid_search.cv_results_)
scores_df

# %%
df_results = scores_df[['params', 'mean_test_score', 'rank_test_score', 
           'split0_test_score', 'split1_test_score']]
df_results.sort_values(by='rank_test_score')

# %%
predicted = grid_search.predict(X_test)
print(confusion_matrix(y_test, predicted))
print(model_evaluation(y_test, predicted))
